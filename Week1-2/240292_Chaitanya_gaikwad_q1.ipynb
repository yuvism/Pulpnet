# %% [markdown]
# ## I am learning Data Analysis

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("movie.csv")

# %%
data.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
data.head()
data.tail()
# Out:
#                                                     text  label
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1

# %%
data['text']
# Out:
# 0        I grew up (b. 1965) watching and loving the Th...
# 1        When I put this movie in my DVD player, and sa...
# 2        Why do people who do not know what a particula...
# 3        Even though I have great interest in Biblical ...
# 4        Im a die hard Dads Army fan and nothing will e...
#                                ...
# 39995    "Western Union" is something of a forgotten cl...
# 39996    This movie is an incredible piece of work. It ...
# 39997    My wife and I watched this movie because we pl...
# 39998    When I first watched Flatliners, I was amazed....
# 39999    Why would this film be so good, but only gross...
# Name: text, Length: 40000, dtype: object

# %%
data['label']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 39995    1
# 39996    1
# 39997    0
# 39998    1
# 39999    1
# Name: label, Length: 40000, dtype: int64

# %%
data.shape
# Out:
# (40000, 2)

# %% [markdown]
# ### lets see numerical data

# %%
data.describe()
# Out:
#               label
# count  40000.000000
# mean       0.499525
# std        0.500006
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# ### checking for null values

# %%
data.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
i0 = 0
i1 = 0
other_values = []
for label in data['label']:
    if label == 0:
        i0+=1
    elif label == 1:
        i1+=1
    else:
        other_values.append(label)

# %%
print(i0)
print(i1)
print(other_values)
# Out:
# 20019
# 19981
# []

# %%
for review in data['text']:
    print(len(review))
# Out:
# 874
# 1811
# 983
# 351
# 983
# 596
# 1377
# 1489
# 1137
# 1468
# 666
# 1298
# 484
# 863
# 726
# 845
# 5809
# 1320
# 2044
# 1547
# 520
# 799
# 176
# 1583
# 634
# 2699
# 1038
# 205
# 746
# 1450
# 1012
# 834
# 1577
# 1089
# 1668
# 1043
# 1706
# 3808
# 479
# 5450
# 685
# 1169
# 883
# 1263
# 1146
# 968
# 2492
# 272
# 856
# 743
# 995
# 778
# 282
# 2064
# 775
# 1371
# 1051
# 808
# 725
# 2024
# 315
# 2658
# 782
# 719
# 760
# 633
# 1722
# 4466
# 1458
# 753
# 800
# 606
# 1483
# 882
# 668
# 3103
# 1648
# 945
# 3155
# 2131
# 797
# 689
# 1212
# 1223
# 350
# 1125
# 1992
# 945
# 2345
# 1153
# 1118
# 1274
# 488
# 1845
# 855
# 671
# 925
# 2012
# 774
# 1861
# 826
# 4086
# 1270
# 575
# 819
# 789
# 5332
# 2655
# 427
# 410
# 2338
# 1179
# 833
# 443
# 3727
# 1458
# 1039
# 3109
# 3917
# 2117
# 1937
# 1186
# 701
# 1188
# 813
# 2153
# 611
# 798
# 961
# 2148
# 976
# 1298
# 610
# 899
# 606
# 1551
# 3206
# 725
# 1471
# 1727
# 1045
# 409
# 524
# 669
# 683
# 372
# 1215
# 627
# 3560
# 673
# 827
# 252
# 1977
# 701
# ...

# %%
sentiment = data['label'].tolist()
length_of_review = data['text'].apply(lambda x: len(x)).tolist()

# %%
length_of_review
# Out:
# [874,
#  1811,
#  983,
#  351,
#  983,
#  596,
#  1377,
#  1489,
#  1137,
#  1468,
#  666,
#  1298,
#  484,
#  863,
#  726,
#  845,
#  5809,
#  1320,
#  2044,
#  1547,
#  520,
#  799,
#  176,
#  1583,
#  634,
#  2699,
#  1038,
#  205,
#  746,
#  1450,
#  1012,
#  834,
#  1577,
#  1089,
#  1668,
#  1043,
#  1706,
#  3808,
#  479,
#  5450,
#  685,
#  1169,
#  883,
#  1263,
#  1146,
#  968,
#  2492,
#  272,
#  856,
#  743,
#  995,
#  778,
#  282,
#  2064,
#  775,
#  1371,
#  1051,
#  808,
#  725,
#  2024,
#  315,
#  2658,
#  782,
#  719,
#  760,
#  633,
#  1722,
#  4466,
#  1458,
#  753,
#  800,
#  606,
#  1483,
#  882,
#  668,
#  3103,
#  1648,
#  945,
#  3155,
#  2131,
#  797,
#  689,
#  1212,
#  1223,
#  350,
#  1125,
#  1992,
#  945,
#  2345,
#  1153,
#  1118,
#  1274,
#  488,
#  1845,
#  855,
#  671,
#  925,
#  2012,
#  774,
#  1861,
#  826,
#  4086,
#  1270,
#  575,
#  819,
#  789,
#  5332,
#  2655,
#  427,
#  410,
#  2338,
#  1179,
#  833,
#  443,
#  3727,
#  1458,
#  1039,
# ...

# %%
df = pd.read_csv("movie.csv")
df['text_length'] = df['text'].apply(len)

# %% [markdown]
# ### shows number of positive and negative reviews

# %%
df['label'].value_counts()
# Out:
# label
# 0    20019
# 1    19981
# Name: count, dtype: int64

# %%
df['review_length'] = df['text'].apply(len)
df.to_csv("movie_with_length.csv", index=False)

# %%
data = pd.read_csv("movie_with_length.csv")
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['text', 'label', 'text_length', 'review_length'], dtype='object')

# %%
sns.displot(data["text_length"])
